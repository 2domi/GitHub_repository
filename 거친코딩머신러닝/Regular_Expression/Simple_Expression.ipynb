# %%
import  matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %% [markdown]
# # 단순 선형 회귀

# %% [markdown]
# ## 이론

# %%
x_b = np.c_[np.ones((100,1)),x] # 모든 샘플에 index 0번에 1을 추가

# np.linalg.inv는 넘파이 선형대수 모듈(linalg)의 inv(역함수)
# .dot은 행렬 곱셈
theta_best = np.linalg.inv(x_b.T.dot(x_b)).dot(x_b.T).dot(y)
theta_best

#뭐라는거야..ㅋㅋ

# %%
# theta_best를 사용해서 y 값 예측
x_new = np.array([[0],[2]])
x_new_b = np.c_[np.ones((2,1)),x_new]
prediction = x_new_b.dot(theta_best)

plt.plot(x_new,prediction,"r-")
plt.plot(x,y,"b.")
plt.axis([0,2,0,15]) # x축 범위 0~2, y축 범위 0~15 
plt.show()
#녜?

# %% [markdown]
# ## 앞에건 이해안되니까 Library로 ㄱ

# %%
from sklearn.linear_model import LinearRegression

# %%
x = 2 * np.random.randn(100,1)
y = 2*x + 2 * np.random.randn(100,1)

plt.scatter(x,y)
plt.show()

# %%
model_LinearRegression = LinearRegression()

model_LinearRegression.fit(x,y) # 훈련시키기
print(model_LinearRegression.intercept_,  model_LinearRegression.coef_)   
#이거지(Library가 진리다)
# Out:
# [0.09720153] [[1.95576654]]

# %% [markdown]
# # 경사하강법 (implementation) 이론

# %%
import numpy as np

# %%
learning_rate = 0.001 # 학습 진행도
iterations = 1000 # 반복량
m = x_bias.shape[0] # x_bias의 데이터 수

theta = np.random.randn(2,1) # theta 초기화

# %%
for iterations in range(iterations): # 반복량(iterations)만큼 반복하는 for문
        gradients = 2/m*x_bias.T.dot(x_bias.dot(theta)-y)
        theta = theta - (learning_rate*gradients)
    
theta
# Out:
# array([[ 0.57391772],
#        [-0.42247746]])

# %% [markdown]
# # 평균적 경사하강법

# %%
from sklearn.linear_model import SGDRegressor
import random

# %% [markdown]
# ## Scaling 안한거

# %%
model_SGDRegressor = SGDRegressor()
model_SGDRegressor
# Out:
# SGDRegressor()

# %%
model_SGDRegressor.fit(x,y)
# Out:
# c:\Users\SAMSUNG\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\utils\validation.py:1406: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# SGDRegressor()

# %%
plt.plot(x, model_SGDRegressor.predict(x),
             color="red")
plt.scatter(x,y,
                 color="blue")

# %% [markdown]
# # LinearRegression & SGDRegressor 비교!

# %%
plt.scatter(x,y,
                 color="blue")
plt.plot(x,model_LinearRegression.predict(x),
             color="red",
             alpha=0.5,
             linewidth=0.1)
plt.plot(x,model_SGDRegressor.predict(x),
             color="orange",
             alpha=0.5,
             linewidth=0.1)
plt.title("Very Similar Result")
plt.show()

# %%
print(f"LinearRegression : {model_LinearRegression.score(x,y)}")
print(f"SGDRegressor : {model_SGDRegressor.score(x,y)}")
# Out:
# LinearRegression : 0.7862704833338292
# SGDRegressor : 0.7862619312218558
